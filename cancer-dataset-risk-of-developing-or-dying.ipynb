# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/cancer-dataset-risk-of-developing-or-dying/Risk of Developing or Dying From Cancer.csv")

# %%
df
# Out:
#                  Cancer Type  Male Risk Development Percentage  \
# 0                 Any cancer                              41.6
# 1                    Bladder                               3.6
# 2   Brain and nervous system                               0.7
# 3                     Breast                               0.1
# 4           Colon and rectum                               4.3
# 5                  Esophagus                               0.8
# 6           Hodgkin lymphoma                               0.2
# 7    Kidney and renal pelvis                               2.3
# 8         Larynx (voice box)                               0.5
# 9                   Leukemia                               1.9
# 10       Liver and bile duct                               1.5
# 11         Lung and bronchus                               6.3
# 12      Melanoma of the skin                               3.6
# 13          Multiple myeloma                               1.0
# ...

# %%
df.plot()
plt.show()

# %%
df.plot(kind="box")
plt.show()

# %%
df.plot(kind="hist")
plt.show()

# %%
new_df=df.drop(columns=["Cancer Type"])
target=df[["Cancer Type"]]

# %%
plt.hist(new_df)
plt.show()

# %%
plt.violinplot(new_df)
plt.show()

# %%
sns.heatmap(new_df)
# Out:
# <Axes: >

# %%
df2=new_df.corr()
sns.heatmap(df2)
# Out:
# <Axes: >

# %%
sns.clustermap(new_df)

# %%
sns.lineplot(new_df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %%
sns.barplot(new_df)
# Out:
# <Axes: >

# %%
sns.violinplot(new_df)
# Out:
# <Axes: >

# %%
sns.violinplot(x="Male Risk Development Percentage",y="Female Risk Development Percentage",data=new_df)
# Out:
# <Axes: xlabel='Male Risk Development Percentage', ylabel='Female Risk Development Percentage'>

# %%
new_df.columns
# Out:
# Index(['Male Risk Development Percentage',
#        'Male Risk Development Ratio(One in ____ Person)',
#        'Male Risk Dying Percentage',
#        'Male Risk Dying Ratio(One in ____ Person)',
#        'Female Risk Development Percentage',
#        'Female Risk Development Ratio(One in ____ Person)',
#        'Female Risk Dying Percentage',
#        'Female Risk Dying Ratio(One in ____ Person)'],
#       dtype='object')

# %%
sns.boxplot(x="Male Risk Development Percentage",y="Female Risk Development Percentage",data=new_df)
# Out:
# <Axes: xlabel='Male Risk Development Percentage', ylabel='Female Risk Development Percentage'>

# %%
sns.violinplot(x='Male Risk Dying Ratio(One in ____ Person)',y='Female Risk Dying Ratio(One in ____ Person)',data=new_df)
# Out:
# <Axes: xlabel='Male Risk Dying Ratio(One in ____ Person)', ylabel='Female Risk Dying Ratio(One in ____ Person)'>

# %%
sns.jointplot(new_df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.FacetGrid(new_df)
