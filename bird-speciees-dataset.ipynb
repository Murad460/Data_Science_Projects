# %%
import numpy as np
import pandas as pd 
from keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
df="/kaggle/input/bird-speciees-dataset/Bird Speciees Dataset"

# %%
datagen=ImageDataGenerator(
rescale=1.0/255,
rotation_range=40,
width_shift_range=0.2, 
height_shift_range=0.2, 
zoom_range=0.2, 
shear_range=0.2,
horizontal_flip=True,
fill_mode="nearest",
validation_split=0.2,)

train_data=datagen.flow_from_directory(
df,
target_size=(256,256),
batch_size=32,
subset="training")

val_data=datagen.flow_from_directory(
df,
target_size=(256,256),
batch_size=32,
subset="validation")
# Out:
# Found 652 images belonging to 6 classes.
# Found 159 images belonging to 6 classes.

# %% [markdown]
# # # CNN

# %%
from keras.layers import Layer,Dense,Conv2D,MaxPooling2D,Input,BatchNormalization,Dropout,ReLU,Flatten
from keras.models import Sequential,Model
from keras.initializers import HeNormal
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %%
early_stopping=EarlyStopping(
monitor='val_loss',
patience=5,
verbose=1)

# %%
inputs=Input(shape=(256,256,3))
C=Conv2D(32,(3,3),activation="relu",padding="same")(inputs)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Conv2D(64,(3,3),padding="same",kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=ReLU()(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Conv2D(128,(3,3),padding="same",kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=ReLU()(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Conv2D(256,(3,3),padding="same",kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=ReLU()(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Conv2D(528,(3,3),padding="same",kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=ReLU()(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Conv2D(1028,(3,3),padding="same",kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=ReLU()(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=MaxPooling2D(pool_size=(2,2),strides=(2,2))(C)

C=Flatten()(C)
C=Dense(64,kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
C=Dense(32,kernel_initializer=HeNormal(),kernel_regularizer=l2(0.01))(C)
C=BatchNormalization()(C)
C=Dropout(0.5)(C)
outputs=Dense(6,activation="softmax")(C)
model=Model(inputs,outputs)
model.compile(optimizer='adam',loss="categorical_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.fit(train_data,epochs=50,validation_data=val_data,callbacks=[early_stopping])
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 170s 7s/step - accuracy: 0.3438 - loss: 43.4704 - val_accuracy: 0.2579 - val_loss: 39.7191
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 194s 7s/step - accuracy: 0.5779 - loss: 37.1749 - val_accuracy: 0.1698 - val_loss: 32.2013
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 154s 7s/step - accuracy: 0.5982 - loss: 29.1736 - val_accuracy: 0.1572 - val_loss: 24.8576
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 202s 7s/step - accuracy: 0.6786 - loss: 22.2139 - val_accuracy: 0.2327 - val_loss: 19.3338
# Epoch 5/50
# ...

# %% [markdown]
# # # QCNN

# %%
# !pip install cirq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.6 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.7/532.7 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.5/596.5 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.8/202.8 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 70.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 62.8 MB/s eta 0:00:00:00:01
# ...

# %%
import cirq
import tensorflow as tf

# %%
len(train_data)
# Out:
# 21

# %%
def build_quantum_circuit(data):
    qubit=[cirq.GridQubit(0,i) for i in range(len(data))]
    circuit=cirq.Circuit()
    for i,value in enumerate(data):
        circuit.append(cirq.rx(value*np.pi).on(qubit[i]))
        circuit.append(cirq.rx(value*np.pi).on(qubit[i]))
        circuit.append(cirq.rx(value*np.pi).on(qubit[i]))
    circuit.append(cirq.CNOT(qubit[0],qubit[1]))
    circuit.append([cirq.measure(qubit[i], key=f'qubit_{i}') for i in range(len(data))])
    return circuit,qubit
def run_quantum_circuit(data):
    results=[]
    for input_data in data:
        circuit,qubit=build_quantum_circuit(input_data)
        simulator=cirq.Simulator()
        result=simulator.run(circuit,repetitions=1)
        for i in range(len(input_data)):
            measure0=result.measurements[f'qubit_{i}'].flatten()[0]
            results.append(measure0)
#         results.append(combine_result)
    return np.array(results,dtype=np.float32)
class QuantumLayer(Layer):
    def __init__(self):
        super(QuantumLayer, self).__init__()
    def call(self,inputs):
        inputs_flat = tf.reshape(inputs, [-1, inputs.shape[-1]]) # Flatten the batch dimension if any

        output=tf.numpy_function(run_quantum_circuit,[inputs_flat],tf.float32)
        output.set_shape(inputs.shape)
        return output
model2=Sequential([
    QuantumLayer(),
    Flatten(),
    Dense(6,activation="softmax")
])
model2.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model2.summary()
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ quantum_layer_24 (QuantumLayer) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.fit(train_data,epochs=50,validation_data=val_data,callbacks=[early_stopping])
# Out:
# Epoch 1/50
#  3/21 ━━━━━━━━━━━━━━━━━━━━ 28:47:28 5758s/step - accuracy: 0.1804 - loss: 30.4596
