# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("/kaggle/input/blood-transfusion-classification/blood_transfusion.csv")

# %%
df
# Out:
#      Recency  Frequency  Monetary  Time        Class
# 0          2         50     12500    98      donated
# 1          0         13      3250    28      donated
# 2          1         16      4000    35      donated
# 3          2         20      5000    45      donated
# 4          1         24      6000    77  not donated
# ..       ...        ...       ...   ...          ...
# 743       23          2       500    38  not donated
# 744       21          2       500    52  not donated
# 745       23          3       750    62  not donated
# 746       39          1       250    39  not donated
# 747       72          1       250    72  not donated
#
# [748 rows x 5 columns]

# %%
X=df.drop(columns=["Class"])
Y=df["Class"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=42)

# %%
random_class=RandomForestClassifier(n_estimators=50)
random_class.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
random_class.score(X_test,Y_test)
# Out:
# 0.7333333333333333
