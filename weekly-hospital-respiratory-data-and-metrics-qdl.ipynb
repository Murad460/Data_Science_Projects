# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/weekly-hospital-respiratory-data-and-metrics/raw_weekly_hospital_respiratory_data_2020_2024.csv")

# %%
df=df.drop(columns=["Week Ending Date","Geographic aggregation"])

# %%
df.columns
# Out:
# Index(['Number of Inpatient Beds', 'Number of Adult Inpatient Beds',
#        'Number of Pediatric Inpatient beds',
#        'Number of Inpatient Beds Occupied',
#        'Number of Adult Inpatient Beds Occupied',
#        'Number of Pediatric Inpatient Beds Occupied', 'Number of ICU Beds',
#        'Number of Adult ICU Beds', 'Number of Pediatric ICU Beds',
#        'Number of ICU Beds Occupied',
#        ...
#        'Absolute Change in the Percent Hospitals Reporting Adult RSV Admissions from Prior Week',
#        'Absolute Change in the Percent Hospitals Reporting RSV Admissions from Prior Week',
#        'Absolute Change in the Percent Hospitals Reporting Percent Inpatient Beds Occupied from Prior Week',
#        'Absolute Change in the Percent Hospitals Reporting Percent ICU Beds Occupied from Prior Week',
#        'Absolute Change in the Percent Hospitals Reporting Percent Inpatient Beds Occupied by COVID-19 Patients from Prior Week',
# ...

# %%
df2=df.dropna(how="any",axis=0)
df2.isnull().sum().sum()
# Out:
# 0

# %%
df2.dtypes
# Out:
# Number of Inpatient Beds                                                                                                    float64
# Number of Adult Inpatient Beds                                                                                              float64
# Number of Pediatric Inpatient beds                                                                                          float64
# Number of Inpatient Beds Occupied                                                                                           float64
# Number of Adult Inpatient Beds Occupied                                                                                     float64
#                                                                                                                              ...
# Absolute Change in the Percent Hospitals Reporting Percent Inpatient Beds Occupied by Influenza Patients from Prior Week    float64
# ...

# %%
plt.plot(df2)
plt.show()

# %%
df2.describe()
# Out:
#        Number of Inpatient Beds  Number of Adult Inpatient Beds  \
# count                208.000000                      208.000000
# mean               23809.951923                    21101.100962
# std                80648.955567                    71376.107046
# min                  293.000000                      249.000000
# 25%                 3488.500000                     3067.500000
# 50%                 8109.500000                     7351.000000
# 75%                16183.500000                    14202.000000
# max               708809.000000                   627230.000000
#
#        Number of Pediatric Inpatient beds  Number of Inpatient Beds Occupied  \
# count                          208.000000                         208.000000
# mean                          2437.456731                       17111.365385
# std                           8391.636031                       58306.262190
# min                              5.000000                         185.000000
# ...

# %%
# import itertools

# for col1, col2 in itertools.combinations(df2.columns, 10):
#     sns.boxplot(x=df2[col1], y=df2[col2])
#     plt.title(f"Boxplot of {col1} vs {col2}")
#     plt.show()

# %%
import itertools

for col1, col2 in itertools.combinations(df2.columns, 10):
    sns.boxplot(x=df2[col1], y=df2[col2])
    plt.title(f"Boxplot of {col1} vs {col2}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 4
#       1 import itertools
#       3 for col1, col2 in itertools.combinations(df2.columns, 2):
# ----> 4     sns.boxplot(x=df2[col1], y=df2[col2])
#       5     plt.title(f"Boxplot of {col1} vs {col2}")
#       6     plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# --> 888     self.draw_boxplot(ax, boxplot_kws)
# ...
