# %%
import numpy as np
import pandas as pd
from scipy.sparse import coo_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv("/kaggle/input/gestational-diabetes/Gestational Diabetes.csv")

# %%
df.isnull().sum()
# Out:
# Age             0
# Pregnancy No    0
# Weight          0
# Height          0
# BMI             0
# Heredity        0
# Prediction      0
# dtype: int64

# %%
df
# Out:
#        Age  Pregnancy No  Weight  Height   BMI  Heredity  Prediction
# 0     17.0           1.0    48.0   165.0  17.6         0           0
# 1     17.0           1.0    49.0   145.0  23.3         0           0
# 2     17.0           1.0    50.0   140.0  25.5         0           0
# 3     17.0           1.0    50.0   145.0  23.8         0           0
# 4     17.0           1.0    49.0   146.0  23.0         0           0
# ...    ...           ...     ...     ...   ...       ...         ...
# 1007  35.0           3.0    89.0   159.0  35.2         1           1
# 1008  41.0           4.0    87.0   165.0  32.0         0           0
# 1009  34.0           2.0    67.0   160.0  26.2         1           0
# 1010  33.0           3.0    65.0   167.0  23.3         0           1
# 1011  28.0           2.0    68.0   156.0  27.9         0           0
#
# [1012 rows x 7 columns]

# %%
X=df.drop(columns=["Prediction"])
Y=df[["Prediction"]]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
random=RandomForestClassifier(n_estimators=50)
random.fit(X_train,Y_train)
# Out:
# /tmp/ipykernel_33/1642071689.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random.fit(X_train,Y_train)
# RandomForestClassifier(n_estimators=50)

# %%
random.score(X_test,Y_test)
# Out:
# 0.8226600985221675
