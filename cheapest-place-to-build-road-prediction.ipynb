# %% [markdown]
# # Getting Frames from video

# %%
def get_video_frames():
    one_video_frames=[]
    for frames in os.listdir(one_video_frames):
        frames_cv=cv2.imread(frames)
        if frames_cv is not None:
            one_video_frames.append(frames_cv)
    return one_video_frames

# %%
def convt_df(one_video_frames):
    frames_data_df=[]
    frames_df=pd.DataFrame(one_video_frames)
    frames_data_df.append(frames_df)
    return frames_df

# %% [markdown]
# # Find  Standard deviation

# %%
import numpy as np
Std_frames=np.std(frames_df)

# %%
max_angle=max(Std_frames)
min_angle=min(Std_frames)

# %% [markdown]
# # Logic for frames

# %%
if std > max_angle:
    print("Cost of building road is high")
else:
    print("Cost of building road is low")
