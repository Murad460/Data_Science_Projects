# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.svm import SVC

# %%
df=pd.read_csv("/kaggle/input/housing-in-london-boroughs/London_houses.csv")

# %%
df
# Out:
#         no       property_name    price        house_type  sqft  bedrooms  \
# 0        0         Queens Road  1675000             House  2716         5
# 1        1       Seward Street   650000  Flat / Apartment   814         2
# 2        2         Hotham Road   735000  Flat / Apartment   761         2
# 3        3        Festing Road  1765000             House  1986         4
# 4        4        Spencer Walk   675000  Flat / Apartment   700         2
# ...    ...                 ...      ...               ...   ...       ...
# 3475  3475   One Lillie Square  3350000   New development  1410         3
# 3476  3476  St. James's Street  5275000  Flat / Apartment  1749         3
# 3477  3477       Ingram Avenue  5995000             House  4435         6
# 3478  3478         Cork Street  6300000   New development  1506         3
# 3479  3479    Courtenay Avenue  8650000             House  5395         6
#
#       bathrooms  receptions                 location           city  \
# ...

# %%
new_df=pd.get_dummies(df).astype(int)

# %%
new_df
# Out:
#         no    price  sqft  bedrooms  bathrooms  receptions  \
# 0        0  1675000  2716         5          5           5
# 1        1   650000   814         2          2           2
# 2        2   735000   761         2          2           2
# 3        3  1765000  1986         4          4           4
# 4        4   675000   700         2          2           2
# ...    ...      ...   ...       ...        ...         ...
# 3475  3475  3350000  1410         3          3           3
# 3476  3476  5275000  1749         3          3           3
# 3477  3477  5995000  4435         6          6           6
# 3478  3478  6300000  1506         3          3           3
# 3479  3479  8650000  5395         6          6           6
#
#       property_name_1 Eastfields Avenue  property_name_10 Park Drive  \
# 0                                     0                            0
# 1                                     0                            0
# ...

# %%
X=new_df.drop(columns=["price"])
Y=new_df["price"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_test,Y_test)
# Out:
# -373125267976602.2

# %%
rand_reg=RandomForestRegressor()
rand_reg.fit(X_train,Y_train)
rand_reg.score(X_test,Y_test)
# Out:
# 0.6677078140193424

# %%
grad_reg=GradientBoostingRegressor()
grad_reg.fit(X_train,Y_train)
grad_reg.score(X_test,Y_test)
# Out:
# 0.678531579684144

# %%
svm_reg=SVC()
svm_reg.fit(X_train,Y_train)
svm_reg.score(X_test,Y_test)
# Out:
# 0.02442528735632184

# %%
inputs=X_test.iloc[2]
array_reshape=np.reshape(inputs,(1,-1))
print(array_reshape)
predict=rand_reg.predict(array_reshape)
predict
# Out:
# [[1298 2953    7 ...    0    0    0]]
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2418350.])

# %%
X_test.iloc[2]
# Out:
# no                      1298
# sqft                    2953
# bedrooms                   7
# bathrooms                  7
# receptions                 7
#                         ...
# postal_code_WD19 4TS       0
# postal_code_WD23 2RG       0
# postal_code_WD23 2RH       0
# postal_code_WD23 3EW       0
# postal_code_WD7 9HJ        0
# Name: 1298, Length: 5951, dtype: int64

# %%
Y_test.iloc[2]
# Out:
# 2700000
