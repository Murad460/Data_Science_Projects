# %% [markdown]
# <a href="https://www.kaggle.com/code/fundial/yeast-csv-60-07-kb-analysis?scriptVersionId=222558217" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/kaggle/input/yeastcsv/yeast.csv")

# %%
df.columns
# Out:
# Index(['mcg', 'gvh', 'alm', 'mit', 'erl', 'pox', 'vac', 'nuc', 'name'], dtype='object')

# %% [markdown]
# Index(['mcg', 'gvh', 'alm', 'mit', 'erl', 'pox', 'vac', 'nuc', 'name'], dtype='object')

# %%
df
# Out:
#        mcg   gvh   alm   mit  erl  pox   vac   nuc name
# 0     0.58  0.61  0.47  0.13  0.5  0.0  0.48  0.22  MIT
# 1     0.43  0.67  0.48  0.27  0.5  0.0  0.53  0.22  MIT
# 2     0.64  0.62  0.49  0.15  0.5  0.0  0.53  0.22  MIT
# 3     0.58  0.44  0.57  0.13  0.5  0.0  0.54  0.22  NUC
# 4     0.42  0.44  0.48  0.54  0.5  0.0  0.48  0.22  MIT
# ...    ...   ...   ...   ...  ...  ...   ...   ...  ...
# 1479  0.81  0.62  0.43  0.17  0.5  0.0  0.53  0.22  ME2
# 1480  0.47  0.43  0.61  0.40  0.5  0.0  0.48  0.47  NUC
# 1481  0.67  0.57  0.36  0.19  0.5  0.0  0.56  0.22  ME2
# 1482  0.43  0.40  0.60  0.16  0.5  0.0  0.53  0.39  NUC
# 1483  0.65  0.54  0.54  0.13  0.5  0.0  0.53  0.22  CYT
#
# [1484 rows x 9 columns]

# %%
label_encoder=LabelEncoder()
df["name"]=label_encoder.fit_transform(df["name"])

# %%
X=df.drop(columns=["name"])
Y=df["name"]

# %%
plt.plot(X)
plt.plot(Y)
plt.show()

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(X)
# Out:
# <Axes: >

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %%
sns.violinplot(X)
# Out:
# <Axes: >

# %%
sns.kdeplot(X)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(X)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.relplot(
    data=X, kind="line",
    x="mcg", y="alm", col="erl",
    hue="vac", size="nuc", style="mit",
    facet_kws=dict(sharex=False),
)

# %%
plt.figure(figsize=(5,20))
sns.displot(data=X, x="mcg", col="vac", kde=True)

# %%
sns.displot(data=X, kind="ecdf", x="gvh", col="pox", hue="nuc", rug=True)

# %%
# Index(['mcg', 'gvh', 'alm', 'mit', 'erl', 'pox', 'vac', 'nuc', 'name'], dtype='object')

sns.catplot(data=X, kind="swarm", x="alm", y="vac", hue="pox")

# %%
sns.catplot(data=X, kind="swarm", x="alm", y="vac", hue="mcg")

# %%
sns.catplot(data=df, kind="swarm", x="alm", y="vac", hue="name")

# %%
sns.catplot(data=df, kind="bar", x="alm", y="vac", hue="name")

# %%
# penguins = sns.load_dataset("penguins")
sns.jointplot(data=df, x="alm", y="vac", hue="name")

# %%
sns.pairplot(data=df, hue="name")

# %%
g = sns.PairGrid(df, hue="name", corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %%
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=df,
    x="mcg", y="alm", hue="name",
    palette="crest", marker="x", s=100,
)
g.set_axis_labels("mcg length (mm)", "alm depth (mm)", labelpad=10)
g.legend.set_title("Name (g)")
g.figure.set_size_inches(6.5, 4.5)
g.ax.margins(.15)
g.despine(trim=True)

# %%
sns.jointplot(data=df, x="mcg", y="alm", hue="name", kind="hist")
