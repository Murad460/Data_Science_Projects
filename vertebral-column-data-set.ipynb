# %% [markdown]
# <a href="https://www.kaggle.com/code/fundial/vertebral-column-data-set?scriptVersionId=219440075" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier,GradientBoostingClassifier,BaggingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv("/kaggle/input/vertebralcolumndataset/Dataset_spine.csv")

# %%
df.isnull().sum()
# Out:
# pelvic incidence               0
#  pelvic tilt                   0
#  lumbar lordosis angle         0
#  sacral slope                  0
#  pelvic radius                 0
#  grade of spondylolisthesis    0
# Class_att                      0
# dtype: int64

# %%
df.nunique()
# Out:
# pelvic incidence               310
#  pelvic tilt                   310
#  lumbar lordosis angle         280
#  sacral slope                  281
#  pelvic radius                 310
#  grade of spondylolisthesis    310
# Class_att                        2
# dtype: int64

# %%
label_encoder=LabelEncoder()
df["Class_att"]=label_encoder.fit_transform(df["Class_att"])

# %%
df
# Out:
#      pelvic incidence   pelvic tilt   lumbar lordosis angle   sacral slope  \
# 0           63.027817     22.552586               39.609117      40.475232
# 1           39.056951     10.060991               25.015378      28.995960
# 2           68.832021     22.218482               50.092194      46.613539
# 3           69.297008     24.652878               44.311238      44.644130
# 4           49.712859      9.652075               28.317406      40.060784
# ..                ...           ...                     ...            ...
# 305         47.903565     13.616688               36.000000      34.286877
# 306         53.936748     20.721496               29.220534      33.215251
# 307         61.446597     22.694968               46.170347      38.751628
# 308         45.252792      8.693157               41.583126      36.559635
# 309         33.841641      5.073991               36.641233      28.767649
#
#       pelvic radius   grade of spondylolisthesis  Class_att
# ...

# %%
X=df.drop(columns=["Class_att"])
Y=df["Class_att"]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
for i in [RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1, random_state=42),
          GradientBoostingClassifier(),GaussianNB(),MLPClassifier(),
          QuadraticDiscriminantAnalysis(),GaussianProcessClassifier(),
          AdaBoostClassifier(),BaggingClassifier(),LogisticRegression(),
          KNeighborsClassifier(),DecisionTreeClassifier(),
          SVC(kernel="linear", C=0.025, random_state=42),SVC(gamma=2, C=1, random_state=42)
]:
    random_reg=i
    random_reg.fit(X_train,Y_train)
    print(f"The accuracy of {i}:",random_reg.score(X_test,Y_test))
# Out:
# The accuracy of RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10,
#                        random_state=42): 0.7741935483870968
# The accuracy of GradientBoostingClassifier(): 0.7580645161290323
# The accuracy of GaussianNB(): 0.7903225806451613
# The accuracy of MLPClassifier(): 0.8064516129032258
# The accuracy of QuadraticDiscriminantAnalysis(): 0.8064516129032258
# The accuracy of GaussianProcessClassifier(): 0.8225806451612904
# The accuracy of AdaBoostClassifier(): 0.8225806451612904
# The accuracy of BaggingClassifier(): 0.8548387096774194
# The accuracy of LogisticRegression(): 0.8548387096774194
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# The accuracy of KNeighborsClassifier(): 0.8387096774193549
# The accuracy of DecisionTreeClassifier(): 0.7741935483870968
# ...
