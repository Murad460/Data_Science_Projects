# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2
# Out:
#               Open          High           Low         Close     Adj Close  \
# 0       465.864014    468.174011    452.421997    457.334015    457.334015
# 1       456.859985    456.859985    413.104004    424.440002    424.440002
# 2       424.102997    427.834991    384.532013    394.795990    394.795990
# 3       394.673004    423.295990    389.882996    408.903992    408.903992
# 4       408.084991    412.425995    393.181000    398.821014    398.821014
# ...            ...           ...           ...           ...           ...
# 2742  41246.132813  41454.410156  40668.042969  41077.996094  41077.996094
# 2743  41074.105469  43124.707031  40948.281250  42358.808594  42358.808594
# 2744  42364.378906  42893.507813  41877.507813  42892.957031  42892.957031
# 2745  42886.652344  44131.855469  42726.164063  43960.933594  43960.933594
# 2746  43958.675781  44982.519531  43711.871094  44395.964844  44395.964844
#
#            Volume
# 0        21056800
# 1        34483200
# ...

# %%
df=pd.read_csv("/kaggle/input/bitcoin-price-prediction-dataset/BTC-USD(1).csv")
df2=pd.read_csv("/kaggle/input/bitcoin-price-prediction-dataset/bitcoin_price_Training - Training.csv")

# %%
df.sample()
df3=df.drop(columns=["Date"])

# %%
df.nunique()
# Out:
# Date         2747
# Open         2743
# High         2744
# Low          2746
# Close        2744
# Adj Close    2744
# Volume       2747
# dtype: int64

# %%
df2.sample()
# Out:
#             Date     Open     High      Low    Close         Volume  \
# 75  May 17, 2017  1726.73  1864.05  1661.91  1839.09  1,064,730,000
#
#         Market Cap
# 75  28,204,800,000

# %%
df2.nunique()
# Out:
# Date          1556
# Open          1529
# High          1527
# Low           1539
# Close         1529
# Volume        1314
# Market Cap    1552
# dtype: int64

# %%
df.plot()
plt.show()

# %%
for i in df3.columns:
    plt.figure(figsize=(8, 6))
    sns.kdeplot(df3[i], shade=True)
    plt.title(f'KDE Plot for {i}')
    plt.show()
# Out:
# /tmp/ipykernel_36/2442713542.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df3[i], shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_36/2442713542.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df3[i], shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
for i in (df3.columns):
    sns.histplot(df3[i],kde=True)
    plt.title(f"hist plot {i}")
    plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for i in df3.columns:
    sns.boxplot(df3[i])
    plt.title(f"box plot {i}")
    plt.show()
