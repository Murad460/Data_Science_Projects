# %% [markdown]
# <a href="https://www.kaggle.com/code/fundial/sleep-deprivation-dataset-detailed-csv-3-58-kb?scriptVersionId=222643302" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import LabelEncoder
import  matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/kaggle/input/sleep-deprivation-and-cognitive-performance/sleep_deprivation_dataset_detailed.csv")

# %%
df
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0              P1         5.25                   15                  12
# 1              P2         8.70                   12                  14
# 2              P3         7.39                   17                  10
# 3              P4         6.59                   14                   3
# 4              P5         3.94                   20                  12
# 5              P6         3.94                   12                   6
# 6              P7         3.35                    8                  18
# 7              P8         8.20                   14                  21
# 8              P9         6.61                   12                   1
# 9             P10         7.25                    0                   9
# 10            P11         3.12                    6                  12
# 11            P12         8.82                    8                  24
# ...

# %%
label_encoder=LabelEncoder()
df["Gender"]=label_encoder.fit_transform(df["Gender"])
df["Participant_ID"]=label_encoder.fit_transform(df["Participant_ID"])

# %%
df
# Out:
#     Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0                0         5.25                   15                  12
# 1               11         8.70                   12                  14
# 2               22         7.39                   17                  10
# 3               33         6.59                   14                   3
# 4               44         3.94                   20                  12
# 5               55         3.94                   12                   6
# 6               57         3.35                    8                  18
# 7               58         8.20                   14                  21
# 8               59         6.61                   12                   1
# 9                1         7.25                    0                   9
# 10               2         3.12                    6                  12
# 11               3         8.82                    8                  24
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.sample()
# Out:
#     Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 26              19          4.2                    6                  12
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 26                       1.79            61.51                        42
#
#     PVT_Reaction_Time  Age  Gender    BMI  Caffeine_Intake  \
# 26              298.0   43       1  22.23                4
#
#     Physical_Activity_Level  Stress_Level
# 26                        0            15

# %%
sns.relplot(
    data=df, kind="line",
    x="Sleep_Hours", y="Sleep_Quality_Score",
    estimator=None,
)

# %%
sns.relplot(
    data=df, kind="line",
    x="Emotion_Regulation_Score", y="Sleep_Quality_Score",
    estimator=None,
)

# %%
sns.relplot(
    data=df, kind="line",
    x="Daytime_Sleepiness", y="Sleep_Quality_Score",
    estimator=None,
)

# %%
sns.relplot(
    data=df, kind="line",
    x="Daytime_Sleepiness", y="BMI", errorbar="sd",
)

# %%
sns.relplot(
    data=df, kind="line",
    x="Sleep_Hours", y="Stress_Level", errorbar="sd",
)

# %%
sns.relplot(
    data=df, x="Sleep_Hours", y="Emotion_Regulation_Score",
    size="Gender", sizes=(15, 200)
)

# %%
sns.relplot(
    data=df, x="Age", y="Emotion_Regulation_Score",
    size="Physical_Activity_Level", sizes=(15, 200)
)

# %%
sns.displot(df, x="Sleep_Hours", hue="Age", multiple="dodge")

# %%
sns.displot(df
            , x="Sleep_Hours", col="Gender")

# %%
sns.displot(df,x="BMI", col="Gender")

# %%
sns.displot(df,x="BMI", y="Sleep_Hours", kind="kde")

# %%
sns.displot(df, x="BMI", y="Sleep_Hours", binwidth=(2, .5))

# %%
sns.displot(df, x="Sleep_Quality_Score", y="Emotion_Regulation_Score", kind="kde", thresh=.2, levels=4)

# %%
sns.jointplot(data=df, x="Emotion_Regulation_Score", y="Sleep_Quality_Score")

# %%
sns.jointplot(data=df, x="Emotion_Regulation_Score", y="Caffeine_Intake")

# %%
sns.pairplot(df)

# %%
g = sns.PairGrid(df)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
df.sample()
# Out:
#     Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 14               6         4.09                    7                  11
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 14                        2.7            75.44                        39
#
#     PVT_Reaction_Time  Age  Gender    BMI  Caffeine_Intake  \
# 14             373.66   29       1  21.96                3
#
#     Physical_Activity_Level  Stress_Level
# 14                        4            19

# %%
sns.catplot(data=df, x="Sleep_Quality_Score", y="Physical_Activity_Level", kind="box")

# %%
sns.catplot(data=df, x="Sleep_Quality_Score", y="Stress_Level", hue="Physical_Activity_Level", kind="box")

# %%
# diamonds = sns.load_dataset("diamonds")
sns.catplot(
    data=df.sort_values("Physical_Activity_Level"),
    x="Physical_Activity_Level", y="Stress_Level", kind="boxen",
)

# %%
sns.catplot(
    data=df, x="Physical_Activity_Level", y="BMI", hue="Gender", kind="violin",
)

# %%
sns.catplot(
    data=df, x="Physical_Activity_Level", y="BMI", hue="Gender",
    kind="violin", split=True,
)

# %%
g = sns.catplot(data=df, x="Physical_Activity_Level", y="Stress_Level", kind="violin", inner=None)
sns.swarmplot(data=df, x="Physical_Activity_Level", y="Stress_Level", color="k", size=3, ax=g.ax)
# Out:
# <Axes: xlabel='Physical_Activity_Level', ylabel='Stress_Level'>

# %%
# tips = sns.load_dataset("tips")
sns.regplot(x="Physical_Activity_Level", y="Stress_Level", data=df);

# %%
def sinplot(n=10, flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, n + 1):
        plt.plot(x, np.sin(x + i * .5) * (n + 2 - i) * flip)
sinplot()
