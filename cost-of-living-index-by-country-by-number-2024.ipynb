# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/cost-of-living-index-by-country-by-number-2024/Cost_of_Living_Index_by_Country_2024.csv")

# %%
df
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Switzerland                 101.1        46.5
# 1       2      Bahamas                  85.0        36.7
# 2       3      Iceland                  83.0        39.2
# 3       4    Singapore                  76.7        67.2
# 4       5     Barbados                  76.6        19.0
# ..    ...          ...                   ...         ...
# 116   117   Bangladesh                  22.5         2.4
# 117   118        India                  21.2         5.6
# 118   119        Egypt                  21.0         3.7
# 119   120        Libya                  20.4         4.3
# 120   121     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# ...

# %%
X=df.drop(columns=["Country"])
Y=df[["Country"]]

# %%
df.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,7),)
df.hist()
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Cost of Living Index'}>,
#         <Axes: title={'center': 'Rent Index'}>],
#        [<Axes: title={'center': 'Cost of Living Plus Rent Index'}>,
#         <Axes: title={'center': 'Groceries Index'}>,
#         <Axes: title={'center': 'Restaurant Price Index'}>],
#        [<Axes: title={'center': 'Local Purchasing Power Index'}>,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(11,7))
df.boxplot()
# Out:
# <Axes: >

# %%
df_melted = pd.melt(df, id_vars=Y, value_vars=X, var_name='Variable', value_name='Value')
plt.figure(figsize=(12,7))
# Create a violin plot
sns.violinplot(x='Variable', y='Value', data=df_melted, palette='muted', inner='quartile')

# Show the plot
plt.show()

# %%
df_melted = pd.melt(df, id_vars=Y, value_vars=X, var_name='Variable', value_name='Value')
plt.figure(figsize=(12,7))
# Create a violin plot
sns.scatterplot(x='Variable', y='Value', data=df_melted, palette='muted')

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_33/4084438598.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Variable', y='Value', data=df_melted, palette='muted')

# %%
df_pie=pd.melt(df,id_vars=Y,value_vars=X,var_name="variable",value_name="value")
plt.pie(X["Cost of Living Index"],labels=Y,autopct='%1.1f%%', colors=['skyblue', 'orange', 'lightgreen'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7856a4c836d0>],
#  [Text(1.0980029953574149, 0.06625271455680305, 'Country')],
#  [Text(0.598910724740408, 0.036137844303710746, '1.9%')])

# %%
# Create pie charts for each value column
columns =X.columns 

for col in columns:
    plt.figure(figsize=(8, 8))
    plt.pie(df[col], labels=Y, autopct='%1.1f%%', colors=['skyblue', 'orange', 'lightgreen'])
    plt.title(f'Pie Chart for {col}')
    plt.show()
