# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Normal Dataset Preprocessing

# %%
df=pd.read_csv("/content/Normaltrajectories _dataframe_like.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 df=pd.read_csv("/content/Normaltrajectories _dataframe_like.csv")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head(1)

# %%
n_df=df.drop(columns=["Fatigued"])

# %%
a1=np.std(n_df["1"])
a2=np.std(n_df["2"])
a3=np.std(n_df["3"])
a4=np.std(n_df["4"])
a5=np.std(n_df["5"])
a6=np.std(n_df["6"])
a7=np.std(n_df["7"])
a8=np.std(n_df["8"])
a9=np.std(n_df["9"])
a10=np.std(n_df["10"])
a11=np.std(n_df["11"])
a12=np.std(n_df["12"])
a13=np.std(n_df["13"])
a14=np.std(n_df["14"])
a15=np.std(n_df["15"])
a16=np.std(n_df["16"])
a17=np.std(n_df["17"])
a18=np.std(n_df["18"])
a19=np.std(n_df["19"])
a20=np.std(n_df["20"])
a21=np.std(n_df["21"])
a22=np.std(n_df["22"])
a23=np.std(n_df["23"])
a24=np.std(n_df["24"])
a25=np.std(n_df["25"])
a26=np.std(n_df["26"])
a27=np.std(n_df["27"])
a28=np.std(n_df["28"])
a29=np.std(n_df["29"])
a30=np.std(n_df["30"])
a31=np.std(n_df["31"])
a32=np.std(n_df["32"])
a33=np.std(n_df["33"])
a34=np.std(n_df["34"])
a35=np.std(n_df["35"])
a36=np.std(n_df["36"])
a37=np.std(n_df["37"])
a38=np.std(n_df["38"])
a39=np.std(n_df["39"])
a40=np.std(n_df["40"])
a41=np.std(n_df["41"])
a42=np.std(n_df["42"])
a43=np.std(n_df["43"])
a44=np.std(n_df["44"])
a45=np.std(n_df["45"])
a46=np.std(n_df["46"])
a47=np.std(n_df["47"])
a48=np.std(n_df["48"])
a49=np.std(n_df["49"])
a50=np.std(n_df["50"])
a51=np.std(n_df["51"])
a52=np.std(n_df["52"])
a53=np.std(n_df["53"])
a54=np.std(n_df["54"])
a55=np.std(n_df["55"])
a56=np.std(n_df["56"])
a57=np.std(n_df["57"])
a58=np.std(n_df["58"])
a59=np.std(n_df["59"])
a60=np.std(n_df["60"])
a61=np.std(n_df["61"])
a62=np.std(n_df["62"])
a63=np.std(n_df["63"])
a64=np.std(n_df["64"])
a65=np.std(n_df["65"])
a66=np.std(n_df["66"])
a67=np.std(n_df["67"])
a68=np.std(n_df["68"])
a69=np.std(n_df["69"])
a70=np.std(n_df["70"])
a71=np.std(n_df["71"])
a72=np.std(n_df["72"])
a73=np.std(n_df["73"])
a74=np.std(n_df["74"])
a75=np.std(n_df["75"])
a76=np.std(n_df["76"])
a77=np.std(n_df["77"])
a78=np.std(n_df["78"])
a79=np.std(n_df["79"])
a80=np.std(n_df["80"])
a81=np.std(n_df["81"])
a82=np.std(n_df["82"])
a83=np.std(n_df["83"])
a84=np.std(n_df["84"])
a85=np.std(n_df["85"])
a86=np.std(n_df["86"])
a87=np.std(n_df["87"])
a88=np.std(n_df["88"])
a89=np.std(n_df["89"])
a90=np.std(n_df["90"])
a91=np.std(n_df["91"])
a92=np.std(n_df["92"])
a93=np.std(n_df["93"])
a94=np.std(n_df["94"])
a95=np.std(n_df["95"])
a96=np.std(n_df["96"])
a97=np.std(n_df["97"])
a98=np.std(n_df["98"])
a99=np.std(n_df["99"])
a100=np.std(n_df["100"])

# %%
normal_dataset=[]
for _ in range(70):
    for _,row in n_df.iterrows():
        dict1={

          #  "a1": row["1"] + np.random.uniform(a1),
            "a1":row["1"] + np.random.uniform(a1),
            "a2":row["2"] + np.random.uniform(a2),
            "a3":row["3"] + np.random.uniform(a3),
            "a4":row["4"] + np.random.uniform(a4),
            "a5":row["5"] + np.random.uniform(a5),
            "a6":row["6"] + np.random.uniform(a6),
            "a7":row["7"] + np.random.uniform(a7),
            "a8":row["8"] + np.random.uniform(a8),
            "a9":row["9"] + np.random.uniform(a9),
            "a11":row["11"] + np.random.uniform(a10),
            "a10":row["10"] + np.random.uniform(a11),
            "a12":row["12"] + np.random.uniform(a12),
            "a13":row["13"] + np.random.uniform(a13),
            "a14":row["14"] + np.random.uniform(a14),
            "a15":row["15"] + np.random.uniform(a15),
            "a16":row["16"] + np.random.uniform(a16),
            "a17":row["17"] + np.random.uniform(a17),
            "a18":row["18"] + np.random.uniform(a18),
            "a19":row["19"] + np.random.uniform(a19),
            "a20":row["20"] + np.random.uniform(a20),
            "a21":row["21"] + np.random.uniform(a21),
            "a22":row["22"] + np.random.uniform(a22),
            "a23":row["23"] + np.random.uniform(a23),
            "a24":row["24"] + np.random.uniform(a24),
            "a25":row["25"] + np.random.uniform(a25),
            "a26":row["26"] + np.random.uniform(a26),
            "a27":row["27"] + np.random.uniform(a27),
            "a28":row["28"] + np.random.uniform(a28),
            "a29":row["29"] + np.random.uniform(a29),
            "a30":row["30"] + np.random.uniform(a30),
            "a31":row["31"] + np.random.uniform(a31),
            "a32":row["32"] + np.random.uniform(a32),
            "a33":row["33"] + np.random.uniform(a33),
            "a34":row["34"] + np.random.uniform(a34),
            "a35":row["35"] + np.random.uniform(a35),
            "a36":row["36"] + np.random.uniform(a36),
            "a37":row["37"] + np.random.uniform(a37),
            "a38":row["38"] + np.random.uniform(a38),
            "a39":row["39"] + np.random.uniform(a39),
            "a40":row["40"] + np.random.uniform(a40),
            "a41":row["41"] + np.random.uniform(a41),
            "a42":row["42"] + np.random.uniform(a42),
            "a43":row["43"] + np.random.uniform(a43),
            "a44":row["44"] + np.random.uniform(a44),
            "a45":row["45"] + np.random.uniform(a45),
            "a46":row["46"] + np.random.uniform(a46),
            "a47":row["47"] + np.random.uniform(a47),
            "a48":row["48"] + np.random.uniform(a48),
            "a49":row["49"] + np.random.uniform(a49),
            "a50":row["50"] + np.random.uniform(a50),
            "a51":row["51"] + np.random.uniform(a51),
            "a52":row["52"] + np.random.uniform(a52),
            "a53":row["53"] + np.random.uniform(a53),
            "a54":row["54"] + np.random.uniform(a54),
            "a55":row["55"] + np.random.uniform(a55),
            "a56":row["56"] + np.random.uniform(a56),
            "a57":row["57"] + np.random.uniform(a57),
            "a58":row["58"] + np.random.uniform(a58),
            "a59":row["59"] + np.random.uniform(a59),
            "a60":row["60"] + np.random.uniform(a60),
            "a61":row["61"] + np.random.uniform(a61),
            "a62":row["62"] + np.random.uniform(a62),
            "a63":row["63"] + np.random.uniform(a63),
            "a64":row["64"] + np.random.uniform(a64),
            "a65":row["65"] + np.random.uniform(a65),
            "a66":row["66"] + np.random.uniform(a66),
            "a67":row["67"] + np.random.uniform(a67),
            "a68":row["68"] + np.random.uniform(a68),
            "a69":row["69"] + np.random.uniform(a69),
            "a70":row["70"] + np.random.uniform(a70),
            "a71":row["71"] + np.random.uniform(a71),
            "a72":row["72"] + np.random.uniform(a72),
            "a73":row["73"] + np.random.uniform(a73),
            "a74":row["74"] + np.random.uniform(a74),
            "a75":row["75"] + np.random.uniform(a75),
            "a76":row["76"] + np.random.uniform(a76),
            "a77":row["77"] + np.random.uniform(a77),
            "a78":row["78"] + np.random.uniform(a78),
            "a79":row["79"] + np.random.uniform(a79),
            "a80":row["80"] + np.random.uniform(a80),
            "a81":row["81"] + np.random.uniform(a81),
            "a82":row["82"] + np.random.uniform(a82),
            "a83":row["83"] + np.random.uniform(a83),
            "a84":row["84"] + np.random.uniform(a84),
            "a85":row["85"] + np.random.uniform(a85),
            "a86":row["86"] + np.random.uniform(a86),
            "a87":row["87"] + np.random.uniform(a87),
            "a88":row["88"] + np.random.uniform(a88),
            "a89":row["89"] + np.random.uniform(a89),
            "a90":row["90"] + np.random.uniform(a90),
            "a91":row["91"] + np.random.uniform(a91),
            "a92":row["92"] + np.random.uniform(a92),
            "a93":row["93"] + np.random.uniform(a93),
            "a94":row["94"] + np.random.uniform(a94),
            "a95":row["95"] + np.random.uniform(a95),
            "a96":row["96"] + np.random.uniform(a96),
            "a97":row["97"] + np.random.uniform(a97),
            "a98":row["98"] + np.random.uniform(a98),
            "a99":row["99"] + np.random.uniform(a99),
            "a100":row["100"] + np.random.uniform(a100)
              }
        normal_dataset.append(dict1)
#         print(dict1)

# %%
new_normal_dat=pd.DataFrame(normal_dataset)
new_normal_dat.size

# %%
new_normal_dat["Fatigued"] = 0

# %%
len(new_normal_dat)

# %%
shuffle_normal=new_normal_dat.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
shuffle_normal.sample(3)

# %% [markdown]
# # ABnormal Dataset preprocess

# %%
abnormal_dataframe=pd.read_csv("/content/AbNormaltrajectories _datafram_like.csv")

# %%
ab_df=abnormal_dataframe.drop(columns=["Fatigued"])

# %%
ab_df.sample()

# %%
b1=np.std(ab_df["1"])
b2=np.std(ab_df["2"])
b3=np.std(ab_df["3"])
b4=np.std(ab_df["4"])
b5=np.std(ab_df["5"])
b6=np.std(ab_df["6"])
b7=np.std(ab_df["7"])
b8=np.std(ab_df["8"])
b9=np.std(ab_df["9"])
b10=np.std(ab_df["10"])
b11=np.std(ab_df["11"])
b12=np.std(ab_df["12"])
b13=np.std(ab_df["13"])
b14=np.std(ab_df["14"])
b15=np.std(ab_df["15"])
b16=np.std(ab_df["16"])
b17=np.std(ab_df["17"])
b18=np.std(ab_df["18"])
b19=np.std(ab_df["19"])
b20=np.std(ab_df["20"])
b21=np.std(ab_df["21"])
b22=np.std(ab_df["22"])
b23=np.std(ab_df["23"])
b24=np.std(ab_df["24"])
b25=np.std(ab_df["25"])
b26=np.std(ab_df["26"])
b27=np.std(ab_df["27"])
b28=np.std(ab_df["28"])
b29=np.std(ab_df["29"])
b30=np.std(ab_df["30"])
b31=np.std(ab_df["31"])
b32=np.std(ab_df["32"])
b33=np.std(ab_df["33"])
b34=np.std(ab_df["34"])
b35=np.std(ab_df["35"])
b36=np.std(ab_df["36"])
b37=np.std(ab_df["37"])
b38=np.std(ab_df["38"])
b39=np.std(ab_df["39"])
b40=np.std(ab_df["40"])
b41=np.std(ab_df["41"])
b42=np.std(ab_df["42"])
b43=np.std(ab_df["43"])
b44=np.std(ab_df["44"])
b45=np.std(ab_df["45"])
b46=np.std(ab_df["46"])
b47=np.std(ab_df["47"])
b48=np.std(ab_df["48"])
b49=np.std(ab_df["49"])
b50=np.std(ab_df["50"])
b51=np.std(ab_df["51"])
b52=np.std(ab_df["52"])
b53=np.std(ab_df["53"])
b54=np.std(ab_df["54"])
b55=np.std(ab_df["55"])
b56=np.std(ab_df["56"])
b57=np.std(ab_df["57"])
b58=np.std(ab_df["58"])
b59=np.std(ab_df["59"])
b60=np.std(ab_df["60"])
b61=np.std(ab_df["61"])
b62=np.std(ab_df["62"])
b63=np.std(ab_df["63"])
b64=np.std(ab_df["64"])
b65=np.std(ab_df["65"])
b66=np.std(ab_df["66"])
b67=np.std(ab_df["67"])
b68=np.std(ab_df["68"])
b69=np.std(ab_df["69"])
b70=np.std(ab_df["70"])
b71=np.std(ab_df["71"])
b72=np.std(ab_df["72"])
b73=np.std(ab_df["73"])
b74=np.std(ab_df["74"])
b75=np.std(ab_df["75"])
b76=np.std(ab_df["76"])
b77=np.std(ab_df["77"])
b78=np.std(ab_df["78"])
b79=np.std(ab_df["79"])
b80=np.std(ab_df["80"])
b81=np.std(ab_df["81"])
b82=np.std(ab_df["82"])
b83=np.std(ab_df["83"])
b84=np.std(ab_df["84"])
b85=np.std(ab_df["85"])
b86=np.std(ab_df["86"])
b87=np.std(ab_df["87"])
b88=np.std(ab_df["88"])
b89=np.std(ab_df["89"])
b90=np.std(ab_df["90"])
b91=np.std(ab_df["91"])
b92=np.std(ab_df["92"])
b93=np.std(ab_df["93"])
b94=np.std(ab_df["94"])
b95=np.std(ab_df["95"])
b96=np.std(ab_df["96"])
b97=np.std(ab_df["97"])
b98=np.std(ab_df["98"])
b99=np.std(ab_df["99"])
b100=np.std(ab_df["100"])

# %%
abnormal_dataset=[]
for _ in range(70):
    for _,row in ab_df.iterrows():
        dict2={

          #  "a1": row["1"] + np.random.uniform(a1),
            "a1":row["1"] + np.random.uniform(b1),
            "a2":row["2"] + np.random.uniform(b2),
            "a3":row["3"] + np.random.uniform(b3),
            "a4":row["4"] + np.random.uniform(b4),
            "a5":row["5"] + np.random.uniform(b5),
            "a6":row["6"] + np.random.uniform(b6),
            "a7":row["7"] + np.random.uniform(b7),
            "a8":row["8"] + np.random.uniform(b8),
            "a9":row["9"] + np.random.uniform(b9),
            "a11":row["11"] + np.random.uniform(b10),
            "a10":row["10"] + np.random.uniform(b11),
            "a12":row["12"] + np.random.uniform(b12),
            "a13":row["13"] + np.random.uniform(b13),
            "a14":row["14"] + np.random.uniform(b14),
            "a15":row["15"] + np.random.uniform(b15),
            "a16":row["16"] + np.random.uniform(b16),
            "a17":row["17"] + np.random.uniform(b17),
            "a18":row["18"] + np.random.uniform(b18),
            "a19":row["19"] + np.random.uniform(b19),
            "a20":row["20"] + np.random.uniform(b20),
            "a21":row["21"] + np.random.uniform(b21),
            "a22":row["22"] + np.random.uniform(b22),
            "a23":row["23"] + np.random.uniform(b23),
            "a24":row["24"] + np.random.uniform(b24),
            "a25":row["25"] + np.random.uniform(b25),
            "a26":row["26"] + np.random.uniform(b26),
            "a27":row["27"] + np.random.uniform(b27),
            "a28":row["28"] + np.random.uniform(b28),
            "a29":row["29"] + np.random.uniform(b29),
            "a30":row["30"] + np.random.uniform(b30),
            "a31":row["31"] + np.random.uniform(b31),
            "a32":row["32"] + np.random.uniform(b32),
            "a33":row["33"] + np.random.uniform(b33),
            "a34":row["34"] + np.random.uniform(b34),
            "a35":row["35"] + np.random.uniform(b35),
            "a36":row["36"] + np.random.uniform(b36),
            "a37":row["37"] + np.random.uniform(b37),
            "a38":row["38"] + np.random.uniform(b38),
            "a39":row["39"] + np.random.uniform(b39),
            "a40":row["40"] + np.random.uniform(b40),
            "a41":row["41"] + np.random.uniform(b41),
            "a42":row["42"] + np.random.uniform(b42),
            "a43":row["43"] + np.random.uniform(b43),
            "a44":row["44"] + np.random.uniform(b44),
            "a45":row["45"] + np.random.uniform(b45),
            "a46":row["46"] + np.random.uniform(b46),
            "a47":row["47"] + np.random.uniform(b47),
            "a48":row["48"] + np.random.uniform(b48),
            "a49":row["49"] + np.random.uniform(b49),
            "a50":row["50"] + np.random.uniform(b50),
            "a51":row["51"] + np.random.uniform(b51),
            "a52":row["52"] + np.random.uniform(b52),
            "a53":row["53"] + np.random.uniform(b53),
            "a54":row["54"] + np.random.uniform(b54),
            "a55":row["55"] + np.random.uniform(b55),
            "a56":row["56"] + np.random.uniform(b56),
            "a57":row["57"] + np.random.uniform(b57),
            "a58":row["58"] + np.random.uniform(b58),
            "a59":row["59"] + np.random.uniform(b59),
            "a60":row["60"] + np.random.uniform(b60),
            "a61":row["61"] + np.random.uniform(b61),
            "a62":row["62"] + np.random.uniform(b62),
            "a63":row["63"] + np.random.uniform(b63),
            "a64":row["64"] + np.random.uniform(b64),
            "a65":row["65"] + np.random.uniform(b65),
            "a66":row["66"] + np.random.uniform(b66),
            "a67":row["67"] + np.random.uniform(b67),
            "a68":row["68"] + np.random.uniform(b68),
            "a69":row["69"] + np.random.uniform(b69),
            "a70":row["70"] + np.random.uniform(b70),
            "a71":row["71"] + np.random.uniform(b71),
            "a72":row["72"] + np.random.uniform(b72),
            "a73":row["73"] + np.random.uniform(b73),
            "a74":row["74"] + np.random.uniform(b74),
            "a75":row["75"] + np.random.uniform(b75),
            "a76":row["76"] + np.random.uniform(b76),
            "a77":row["77"] + np.random.uniform(b77),
            "a78":row["78"] + np.random.uniform(b78),
            "a79":row["79"] + np.random.uniform(b79),
            "a80":row["80"] + np.random.uniform(b80),
            "a81":row["81"] + np.random.uniform(b81),
            "a82":row["82"] + np.random.uniform(b82),
            "a83":row["83"] + np.random.uniform(b83),
            "a84":row["84"] + np.random.uniform(b84),
            "a85":row["85"] + np.random.uniform(b85),
            "a86":row["86"] + np.random.uniform(b86),
            "a87":row["87"] + np.random.uniform(b87),
            "a88":row["88"] + np.random.uniform(b88),
            "a89":row["89"] + np.random.uniform(b89),
            "a90":row["90"] + np.random.uniform(b90),
            "a91":row["91"] + np.random.uniform(b91),
            "a92":row["92"] + np.random.uniform(b92),
            "a93":row["93"] + np.random.uniform(b93),
            "a94":row["94"] + np.random.uniform(b94),
            "a95":row["95"] + np.random.uniform(b95),
            "a96":row["96"] + np.random.uniform(b96),
            "a97":row["97"] + np.random.uniform(b97),
            "a98":row["98"] + np.random.uniform(b98),
            "a99":row["99"] + np.random.uniform(b99),
            "a100":row["100"] + np.random.uniform(b100)
              }
        abnormal_dataset.append(dict2)
#         print(dict1)

# %%
new_abnormal_dat=pd.DataFrame(abnormal_dataset)

# %%
new_abnormal_dat["Fatigued"] = 1

# %%
new_abnormal_dat.sample(3)

# %%
new_abnormal_dat.size

# %%
len(new_abnormal_dat)

# %%
shuffle_abnormal=new_abnormal_dat.sample(frac=1,random_state=42).reset_index(drop=True)

# %% [markdown]
# # Combine the Model

# %%
combine_model_trajectory=pd.concat([new_abnormal_dat,new_normal_dat])

# %%
combine_model_trajectory.sample(3)

# %%
combine_model_trajectory.size

# %%
len(combine_model_trajectory)

# %%
combine_model_trajectory.isnull().sum()

# %% [markdown]
# # Deep Learning Model

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,LSTM,SimpleRNN,GRU,Dropout,Flatten,Input
from keras.preprocessing.sequence import pad_sequences

# %%
import tensorflow as tf

# Define the EarlyStopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',   # Quantity to be monitored (e.g., validation loss)
    patience=5,           # Number of epochs with no improvement after which training will be stopped
    verbose=1,            # Verbosity mode (0: silent, 1: update messages)
    restore_best_weights=True  # Restore the model weights from the epoch with the best value of the monitored quantity
)

# %%
# combine_model_trajectory.to_csv("combine_model_trajectory.csv")

# %%
combine_d=pd.read_csv("/kaggle/input/new-combine-gait/combine_model_trajectory_new_format")

# %%
combine_df=combine_d.drop(columns=["Unnamed: 0"])

# %%
combine_df.describe()
# Out:
#                  a1            a2            a3            a4            a5  \
# count  24570.000000  24570.000000  24570.000000  24570.000000  24570.000000
# mean      28.575981     29.671777     30.627887     31.333059     32.060641
# std       17.712066     18.153926     18.120475     17.833131     17.869418
# min        1.314398      1.401257      1.672624      1.623273      1.173444
# 25%       17.030622     17.854494     18.601122     19.006111     19.451365
# 50%       25.664825     26.541095     27.554531     28.413311     29.215384
# 75%       34.831456     36.273752     37.875365     39.326984     40.793248
# max      195.196188    202.352410    189.828098    182.522939    187.568944
#
#                  a6            a7            a8            a9           a11  \
# count  24570.000000  24570.000000  24570.000000  24570.000000  24570.000000
# mean      33.196598     34.353247     35.268822     36.096365     37.787141
# ...

# %%
X=combine_df.iloc[:,:-1]
Y=combine_df["Fatigued"]

# %%
combine_df.size
# Out:
# 2481570

# %%
X.head(1)
# Out:
#           a1         a2        a3         a4         a5         a6         a7  \
# 0  34.999858  28.059315  28.09698  34.807974  29.601965  28.010723  25.272352
#
#           a8         a9        a11  ...        a91        a92        a93  \
# 0  31.762367  20.379132  20.906112  ...  23.223695  22.508722  19.614025
#
#          a94        a95        a96        a97        a98        a99       a100
# 0  19.415918  16.702434  22.533988  16.700741  17.410996  21.457702  20.117435
#
# [1 rows x 100 columns]

# %%
# X.sample()
Y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 24565    0
# 24566    0
# 24567    0
# 24568    0
# 24569    0
# Name: Fatigued, Length: 24570, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

# %%
X_train.shape
# Out:
# (18427, 100)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (18427, 100)
# (18427,)

# %%
Y_train
# Out:
# 10383    1
# 21803    0
# 966      1
# 18407    0
# 291      1
#         ..
# 21301    0
# 18811    0
# 8623     1
# 6072     1
# 24312    0
# Name: Fatigued, Length: 18427, dtype: int64

# %%
X_train_values=X_train.values
X_train_reshaped=X_train_values.reshape(X_train_values.shape[0],1,X_train_values.shape[1])
X_test_values=X_test.values
X_test_reshaped=X_test_values.reshape(X_test_values.shape[0],1,X_test_values.shape[1])

# %%
model3 =Sequential([
    Input(shape=(18427, 100)),
    SimpleRNN(100,return_sequences=True,activation="relu"),
    Dense(100,activation="relu"),
    Dense(200,activation="relu"),
    Dense(200,activation="relu"),
    Dropout(0.5),
    SimpleRNN(400,return_sequences=True,activation="relu"),
    Dense(400,activation="relu"),
    Dense(800,activation="relu"),
    Dense(800,activation="relu"),
    Dropout(0.5),
    SimpleRNN(1600,return_sequences=True,activation="relu"),
    Dense(400,activation="relu"),
    Dense(400,activation="relu"),
    Dense(500,activation="relu"),
    Dropout(0.5),
    SimpleRNN(32,return_sequences=False,activation="relu"),
    Dense(32,activation="relu"),
    Dense(1,activation="sigmoid")
])

# %%
model3.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model3.fit(X_train_reshaped,Y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_reshaped,Y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/100
#  28/576 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6602 - loss: 0.7531
# W0000 00:00:1715685384.068262     103 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7505 - loss: 0.5394
# W0000 00:00:1715685411.080340     103 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1715685412.201794     105 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 43s 51ms/step - accuracy: 0.7506 - loss: 0.5392 - val_accuracy: 0.8481 - val_loss: 0.3292
# Epoch 2/100
#  23/576 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8868 - loss: 0.2589
# W0000 00:00:1715685413.550183     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# ...

# %%
# Assuming model3 is your trained TensorFlow model
model3.save("model3.h5")

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model1=load_model("/kaggle/working/model3.h5")
loaded_model1.predict(value_array1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[430], line 5
#       3 # Load the model
#       4 loaded_model1=load_model("/kaggle/working/model3.h5")
# ----> 5 loaded_model1.predict(value_array1)
#
# NameError: name 'value_array1' is not defined

# %%
loss3,accuracy3=model3.evaluate(X_test_reshaped,Y_test)
print("Loss of Sequential model:",loss3)
print("accuracy of Sequential model:",accuracy3)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8457 - loss: 0.3292
# Loss of Sequential model: 0.32920268177986145
# accuracy of Sequential model: 0.8481197953224182

# %%
model =Sequential([
    Input(shape=(18427, 100)),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(128,activation="relu"),
    Dropout(0.5),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(256,activation="relu"),
    Dense(256,activation="relu"),
    Dropout(0.5),
    Dense(256,activation="relu"),
    Dense(512,activation="relu"),
    Dense(512,activation="relu"),
    Dense(512,activation="relu"),
    Dropout(0.5),
    Dense(256,activation="relu"),
    Dense(128,activation="relu"),
    Dense(64,activation="relu"),
    Dense(32,activation="relu"),
    Dropout(0.5),
    Dense(32,activation="relu"),
    Dense(1,activation="sigmoid")
])
 
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=['accuracy'])
model.fit(X_train_reshaped,Y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_reshaped,Y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/100
#  41/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7301 - loss: 0.6408
# W0000 00:00:1715675632.323638     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7472 - loss: 0.5885
# W0000 00:00:1715675642.310631     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - accuracy: 0.7472 - loss: 0.5885 - val_accuracy: 0.8082 - val_loss: 0.4781
# Epoch 2/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8298 - loss: 0.4121 - val_accuracy: 0.8864 - val_loss: 0.2886
# Epoch 3/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8821 - loss: 0.2886 - val_accuracy: 0.9067 - val_loss: 0.2387
# Epoch 4/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8979 - loss: 0.2492 - val_accuracy: 0.9168 - val_loss: 0.2135
# Epoch 5/100
# ...

# %%
loss,accuracy=model.evaluate(X_test_reshaped,Y_test)

print("Loss of Sequential model:",loss)
print("accuracy of Sequential model:",accuracy)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7990 - loss: 0.4887
# Loss of Sequential model: 0.4781001806259155
# accuracy of Sequential model: 0.8082370162010193

# %%
model2 =Sequential([
    Input(shape=(18427, 100)),
    LSTM(64,return_sequences=True,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dropout(0.5),
    LSTM(128,return_sequences=True,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dropout(0.5),
    LSTM(256,return_sequences=True,activation="relu"),
    Dense(256,activation="relu"),
    Dense(256,activation="relu"),
    Dense(256,activation="relu"),
    Dropout(0.5),
    LSTM(512,return_sequences=True,activation="relu"),
    Dense(512,activation="relu"),
    Dense(512,activation="relu"),
    Dense(256,activation="relu"),
    Dropout(0.5),
    LSTM(32,return_sequences=False,activation="relu"),
    Dense(32,activation="relu"),
    Dense(1,activation="sigmoid")
])
model2.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model2.fit(X_train_reshaped,Y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_reshaped,Y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/100
#  28/576 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7534 - loss: 0.6897
# W0000 00:00:1715676333.031404     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7452 - loss: 0.5995
# W0000 00:00:1715676352.894531     103 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - accuracy: 0.7452 - loss: 0.5994 - val_accuracy: 0.7493 - val_loss: 0.5495
# Epoch 2/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7447 - loss: 0.5604 - val_accuracy: 0.7461 - val_loss: 0.5341
# Epoch 3/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7945 - loss: 0.4534 - val_accuracy: 0.8628 - val_loss: 0.3831
# Epoch 4/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8659 - loss: 0.3176 - val_accuracy: 0.8911 - val_loss: 0.2907
# Epoch 5/100
# ...

# %%
loss2,accuracy2=model2.evaluate(X_test_reshaped,Y_test)
print("Loss of Sequential model:",loss2)
print("accuracy of Sequential model:",accuracy2)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7491 - loss: 0.5523
# Loss of Sequential model: 0.5495370030403137
# accuracy of Sequential model: 0.749308168888092

# %%
model4 =Sequential([
    Input(shape=(18427, 100)),
    GRU(64,return_sequences=True,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dropout(0.5),
    GRU(128,return_sequences=True,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dropout(0.5),
    GRU(256,return_sequences=True,activation="relu"),
    Dense(256,activation="relu"),
    Dense(512,activation="relu"),
    Dense(512,activation="relu"),
    Dropout(0.5),
    GRU(1024,return_sequences=True,activation="relu"),
    Dense(1024,activation="relu"),
    Dense(2048,activation="relu"),
    Dense(2048,activation="relu"),
    Dropout(0.5),
    GRU(1024,return_sequences=True,activation="relu"),
    Dense(512,activation="relu"),
    Dense(256,activation="relu"),
    Dense(128,activation="relu"),
    Dropout(0.5),
    GRU(64,return_sequences=False,activation="relu"),
    Dense(32,activation="relu"),
    Dense(1,activation="sigmoid")
])
model4.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model4.fit(X_train_reshaped,Y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_reshaped,Y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/100
#  13/576 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.6544 - loss: 0.6676
# W0000 00:00:1715676110.327411     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7408 - loss: 0.5832
# W0000 00:00:1715676131.565554     106 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1715676133.492651     103 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 52s 43ms/step - accuracy: 0.7409 - loss: 0.5832 - val_accuracy: 0.7493 - val_loss: 0.5615
# Epoch 2/100
#   1/576 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.8125 - loss: 0.5090
# W0000 00:00:1715676134.856791     105 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# ...

# %%
loss4,accuracy4=model4.evaluate(X_test_reshaped,Y_test)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7491 - loss: 0.5618

# %%
print("Loss of Sequential model:",loss4)
print("accuracy of Sequential model:",accuracy4)
# Out:
# Loss of Sequential model: 0.5636600255966187
# accuracy of Sequential model: 0.749308168888092

# %%
model5 =Sequential([
    Input(shape=(18427, 100)),
    SimpleRNN(64,return_sequences=True,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dropout(0.5),
    SimpleRNN(128,return_sequences=True,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dense(128,activation="relu"),
    Dropout(0.5),
    SimpleRNN(64,return_sequences=False,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dense(64,activation="relu"),
    Dropout(0.5),
    Dense(32,activation="relu"),
    Dense(1,activation="sigmoid")
])
model5.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model5.fit(X_train_reshaped,Y_train,epochs=100,batch_size=32,verbose=1,validation_data=(X_test_reshaped,Y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.7497 - loss: 0.5487 - val_accuracy: 0.8624 - val_loss: 0.3192
# Epoch 2/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8672 - loss: 0.2951 - val_accuracy: 0.9289 - val_loss: 0.1914
# Epoch 3/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9207 - loss: 0.1882 - val_accuracy: 0.9178 - val_loss: 0.2026
# Epoch 4/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9433 - loss: 0.1462 - val_accuracy: 0.9222 - val_loss: 0.1834
# Epoch 5/100
# 576/576 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9567 - loss: 0.1095 - val_accuracy: 0.9674 - val_loss: 0.0971
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
loss5,accuracy5=model5.evaluate(X_test_reshaped,Y_test)
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9584 - loss: 0.0294
print("Loss of Sequential model:",loss5)
print("accuracy of Sequential model:",accuracy5)
# Out:
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3179
# Loss of Sequential model: 0.31924718618392944
# accuracy of Sequential model: 0.862445056438446

# %%
X_test.sample()
# Out:
#               a1        a2         a3         a4         a5         a6  \
# 15281  22.936612  16.25937  22.254892  15.435288  16.187797  16.516521
#
#               a7         a8         a9        a11  ...        a91        a92  \
# 15281  24.144729  14.912356  14.839739  21.022612  ...  38.384893  39.978712
#
#              a93        a94        a95        a96        a97        a98  \
# 15281  41.202735  42.826152  48.002805  48.562428  42.693255  46.392378
#
#              a99      a100
# 15281  46.668352  48.06162
#
# [1 rows x 100 columns]

# %%
# values = [
#     16.14317955, 10.82713936, 19.03686969, 15.64648484, 22.72584961, 22.61353949, 23.3839686, 29.39897786,
#     32.23601043, 28.36771616, 23.2754751, 20.88842685, 22.71988785, 23.34176656, 22.8858413, 31.92422046,
#     24.48936249, 28.14823264, 21.94088309, 26.72964959, 22.32235215, 32.89954871, 28.3485975, 20.66585232,
#     28.09870297, 23.81577943, 38.82870768, 37.06076492, 28.33690256, 34.91944173, 23.69796509, 23.77615693,
#     22.74054557, 26.44997058, 24.59592032, 25.20543258, 21.13528577, 25.80691006, 19.38856046, 21.72919778,
#     23.80801167, 17.52042763, 22.61054271, 20.77203691, 22.87626164, 20.96937148, 19.85131213, 24.07576156,
#     22.00222509, 20.790348, 24.20049094, 21.42831635, 22.19695894, 24.85063856, 31.36273449, 25.51733832,
#     35.33529069, 39.78840502, 45.37913287, 43.56320308, 42.46966987, 51.23713458, 45.7306672, 51.19525907,
#     60.76309448, 51.482913, 57.13222038, 57.79756816, 53.68293261, 53.56190207, 48.78373012, 46.7683667,
#     43.09164554, 46.36333656, 43.37215341, 42.66418815, 47.82204572, 40.49675681, 44.74525808, 41.08089868,
#     37.055386, 30.986113, 28.21209616, 26.2092758, 15.81542439, 11.05821476, 7.882955463, 7.898135581,
#     12.13816238, 5.012590314, 13.19660052, 14.1835931, 17.73942687, 12.33389535, 19.3784519, 20.12375131,
#     17.81904259, 18.36357578, 22.60996352, 18.34115552
# ]

# %%
# values = [
#     13.59455182, 15.55360992, 8.281050551, 18.15390138, 20.49024774, 21.04122284, 13.12619783, 23.31702634,
#     21.15861344, 26.79271802, 24.45918779, 33.07329445, 29.48614052, 24.14948916, 22.09492514, 25.47508229,
#     30.20959705, 36.53095483, 36.09492521, 42.63846057, 36.77167009, 42.04582329, 33.70507858, 43.60308228,
#     40.91941167, 41.20865652, 39.43024532, 23.8317002, 25.42946375, 27.19813919, 19.35273664, 18.61900274,
#     25.98782163, 19.47724006, 21.21923267, 27.17078652, 27.1098, 23.46986041, 22.68607991, 24.4276815, 26.93823343,
#     23.81395162, 26.64236114, 27.41445373, 27.75748875, 33.05278698, 27.0849082, 29.59622269, 35.39733144, 30.05388823,
#     29.54461672, 28.87968606, 37.5341371, 37.19825971, 39.7151882, 42.66823212, 36.09307852, 42.05080942, 47.49318849,
#     44.72628081, 47.46412203, 44.41753311, 46.94695387, 49.86720863, 44.09476996, 49.49876238, 58.7816829, 54.60564361,
#     48.55704391, 58.18759705, 49.5038021, 50.44046887, 45.87205324, 40.57133818, 44.33138879, 43.79392627, 46.4695885,
#     43.3420295, 35.14895109, 31.22588159, 28.20788956, 23.24127482, 19.71509736, 27.65546378, 29.18039736, 31.4575112,
#     28.65517054, 34.41258786, 25.16814816, 22.88844093, 24.16490656, 15.12152784, 16.2646382, 6.878773113,
#     4.545794394, 10.4769306, 6.306559996, 4.537353504, 9.095189807, 8.794051748
# ]

# %%
# values = [
#     14.1, 11.2, 9.41, 9.79, 10.9, 12.8, 14, 15.7, 17.8, 19, 19.8, 19.9, 22, 24.3, 26.2, 27.4, 28.8, 29.7, 30.1, 31.1,
#     30.9, 30.3, 29.7, 29.2, 33.1, 38, 41.6, 46.3, 42.8, 33.9, 25.1, 19.5, 17.5, 17.4, 16.2, 15, 14.3, 14.9, 16.8, 19.3,
#     21.9, 23.4, 24.5, 24.1, 23.3, 23.8, 24.9, 26.1, 27.2, 27.9, 28, 27.7, 27.9, 29.3, 30.7, 31, 32, 34.4, 37.5, 38.7,
#     36.1, 35.7, 38, 38.9, 41.9, 38, 33.8, 30.7, 30.8, 32, 29.4, 28.8, 36, 41.6, 33, 22, 19.5, 17.2, 9.43, 9.03, 8.77,
#     7.12, 5.21, 2.82, 2.23, 5.47, 12.7, 5.44, 7.73, 18, 30.2, 24.5, 10.4, 12.2, 9.83, 10.4, 14.5, 18.1, 17.4, 18.6
# ]

# %%
numbers_list = [
   10.6, 11.2, 11.8, 12.4, 13.8, 15.6, 17.5, 19.4, 21.6, 23.8, 26.0, 27.9, 29.7, 31.5, 32.8, 33.0, 33.2, 33.3, 31.2, 28.9, 
26.6, 24.0, 21.2, 18.4, 15.6, 13.5, 11.5, 9.41, 8.06, 7.03, 6.01, 5.24, 5.14, 5.04, 4.95, 5.12, 5.33, 5.54, 5.59, 5.43, 
5.27, 5.09, 4.48, 3.87, 3.25, 2.68, 2.12, 1.57, 1.11, 1.01, 0.91, 0.81, 1.3, 1.95, 2.59, 3.17, 3.63, 4.1, 4.56, 3.69, 
2.77, 1.85, 1.35, 1.18, 1.02, 0.98, 1.68, 2.38, 3.09, 5.00, 7.37, 9.74, 12.0, 13.9, 15.8, 17.7, 18.9, 20.0, 21.0, 
21.3, 20.8, 20.3, 19.7, 18.9, 18.0, 17.2, 16.6, 16.1, 15.7, 15.1, 14.1, 13.0, 12.0, 11.1, 10.3, 9.39, 8.79, 8.58, 
8.37, 8.15

]

# %%
# abnormal=1
values_a = [
    37.8, 38.3, 39, 40.2, 42.2, 44.5, 46.4, 48.2, 49.9, 51.9, 53.5, 54.4, 54.3, 53, 52, 51.5, 51.8, 51.6, 50.5, 48.8, 46.7,
    45.1, 43.5, 42, 40.7, 39.6, 38.1, 36.1, 33.4, 30.1, 26.7, 23.2, 19.3, 15.7, 12.7, 10.3, 8.03, 6.26, 5.16, 4.7, 4.83,
    5.32, 5.78, 6.05, 5.92, 6.03, 6.67, 7.8, 9.05, 9.92, 10.5, 11, 11.4, 13, 16.2, 20.8, 26, 29.2, 30.5, 30.3, 29.4, 28.7,
    28.5, 28.8, 29.1, 28.1, 26.5, 24.4, 23.2, 25.1, 29.9, 37.2, 43.2, 46.8, 49.1, 50.2, 47.8, 43.3, 38.1, 33.2, 28.9, 25.3,
    22.5, 20.8, 20.4, 19.9, 19.2, 18.1, 16.8, 15.8, 15.5, 16.1, 17.6, 18.8, 19.2, 18.6, 18.1, 18.6, 19.6, 21
]

# %%
#abnormla=1
values_a1 = [
    29.5, 30.9, 32.6, 34.3, 36.3, 38.5, 40.4, 41.6, 42.8, 44.8, 48.3, 53.6, 60.1, 65.4, 68.2, 69.1, 69.3, 69.3, 69.4, 69.0,
    67.0, 63.6, 59.7, 55.8, 51.8, 47.4, 42.8, 38.3, 34.5, 31.0, 26.7, 21.2, 15.8, 12.0, 9.97, 8.4, 6.52, 4.8, 3.66, 2.85,
    2.1, 1.37, 0.65, 0.27, 0.76, 1.84, 2.7, 3.42, 4.59, 5.56, 5.54, 5.15, 5.0, 4.64, 3.76, 2.76, 2.28, 2.72, 4.0, 5.97,
    8.52, 11.1, 13.1, 14.7, 16.7, 18.8, 20.4, 21.0, 20.9, 20.8, 20.8, 20.9, 20.6, 20.1, 20.0, 20.7, 21.7, 22.3, 22.2, 21.6,
    20.1, 17.3, 14.4, 12.8, 12.7, 13.7, 15.3, 17.2, 18.8, 19.9, 20.6, 21.2, 21.7, 22.1, 22.1, 22.0, 22.5, 23.7, 25.4, 27.0
]

# %%
# normal=0
values_n = [
    18.5, 21.4, 24.7, 28.5, 32.5, 36.7, 40.9, 44.9, 48.6, 52.2, 55.9, 59.6, 62.8, 64.7, 65.3, 64.6, 62.7, 61.4, 60.3, 58.9,
    56.8, 54.8, 53.6, 53.2, 53.2, 52.1, 49.6, 45.9, 41.3, 36.1, 30.8, 25.6, 20.8, 16, 11.1, 6.08, 1.21, 3.63, 6.85, 9.42,
    10.2, 9.57, 8.21, 6.39, 4.34, 2.76, 1.61, 0.81, 0.18, 0.83, 2.54, 4.94, 6.62, 5.11, 3.19, 1.74, 1.32, 0.65, 0.2, 0.21,
    1.13, 2.54, 4.37, 6.6, 9.18, 11.5, 13.5, 15.1, 16.3, 17.5, 18.8, 20.1, 21, 21.5, 21.5, 21, 19.5, 17.5, 15.7, 14.1, 13.1,
    12.6, 12.6, 13.1, 14.1, 14.9, 15.6, 16.1, 16.7, 17.2, 17.4, 17.3, 17, 16.9, 17.2, 17.6, 18.1, 18.9, 20.1, 21.7
]

# %%
#normal=0
values_n1= [
    23.4, 26.7, 30.6, 35.1, 40.0, 44.5, 48.8, 52.9, 56.3, 58.5, 59.7, 60.0, 60.1, 60.6, 61.5, 62.7, 63.6, 63.8, 63.5, 63.1,
    63.2, 63.9, 65.1, 65.6, 65.7, 65.0, 63.5, 60.6, 57.2, 53.5, 49.6, 45.1, 40.0, 34.5, 28.8, 23.3, 18.1, 13.7, 10.3, 7.65,
    5.53, 4.2, 3.43, 3.13, 3.28, 4.2, 5.46, 6.94, 8.51, 10.1, 11.5, 12.7, 13.8, 14.2, 14.0, 12.9, 11.0, 9.05, 7.37, 6.43,
    6.5, 7.33, 8.84, 10.9, 12.9, 14.8, 16.6, 18.4, 20.2, 21.9, 23.5, 23.8, 23.4, 22.5, 21.6, 21.2, 20.8, 20.0, 19.0, 18.3,
    17.8, 17.7, 17.0, 16.0, 14.9, 14.5, 14.8, 15.2, 15.6, 15.4, 14.9, 14.5, 14.2, 14.6, 15.2, 16.0, 16.9, 18.1, 19.6, 21.6
]

# %%
# normal=0
values_n2=[9.97, 11.7, 13.5, 15.6, 17.8, 19.7, 21.3, 22.0, 22.3, 22.8, 24.0, 24.7, 24.8, 23.7, 21.5, 19.5, 18.1, 18.9, 20.0, 21.3, 21.0, 19.0, 16.0, 12.7, 10.3, 8.57, 7.56, 6.78, 6.04, 5.29, 4.55, 4.08, 3.95, 4.51, 4.97, 5.24, 4.41, 3.26, 1.96, 0.98, 0.53, 0.51, 1.14, 2.37, 3.87, 5.59, 7.49, 9.72, 12.4, 15.5, 18.4, 21.2, 23.8, 26.4, 29.1, 32.4, 36.2, 40.1, 43.6, 46.1, 48.0, 49.1, 49.4, 49.3, 48.8, 48.9, 49.2, 49.6, 48.7, 46.8, 43.9, 39.4, 34.9, 31.1, 29.8, 29.5, 29.2, 28.4, 26.8, 24.8, 22.4, 19.1, 15.8, 12.3, 9.92, 7.66, 5.6, 4.53, 4.33, 4.55, 4.54, 4.61, 4.84, 5.43, 5.95, 6.44, 6.93, 7.49, 8.07, 8.64]

# %%
#normal=0
values_n3=[9.25, 10.8, 12.3, 14.6, 16.8, 19.3, 22.0, 25.3, 28.7, 32.7, 36.9, 41.5, 45.6, 49.0, 50.8, 50.3, 47.4, 41.8, 34.9, 26.7, 18.8, 10.9, 6.24, 3.25, 4.36, 7.18, 8.79, 10.0, 10.2, 10.2, 9.15, 8.02, 6.63, 5.23, 4.17, 3.12, 2.28, 1.46, 0.8, 0.47, 1.66, 2.83, 3.99, 5.1, 6.1, 7.08, 7.98, 8.99, 10.1, 11.6, 13.3, 15.1, 17.1, 19.2, 21.2, 23.3, 25.5, 27.7, 29.8, 32.1, 34.3, 37.3, 40.4, 43.8, 47.3, 46.8, 46.0, 39.7, 33.5, 28.8, 24.6, 24.3, 24.5, 27.1, 29.8, 33.0, 35.3, 35.3, 33.8, 29.8, 25.9, 22.1, 19.2, 17.3, 15.8, 14.5, 12.9, 11.0, 9.38, 7.83, 6.59, 5.48, 4.82, 4.31, 4.57, 5.0, 5.42, 5.84, 5.19, 4.47]

# %%
tra_df=pd.read_csv("/kaggle/input/normal-trajectory-data/Normaltrajectories _dataframe_like123.csv")

# %%
ref=pd.read_csv("/kaggle/input/ref12-12/ref.csv")

# %%
new_ref=pd.read_csv("/kaggle/input/ref-new-data/ref (1).csv")

# %%
ref.sa
# Out:
#             0
# 72  10.377393

# %%
values_array = np.array(new_ref)

# Reshape the array to match the expected input shape of the model
# If the model expects input shape (None, 16332, 100):
values_array1 = values_array.reshape(-1,1,100)  # Reshape to have batch size 1 and 100 features

# Now, you can use model.predict()
predictions5 = model3.predict(values_array1)
# Apply thresholding to convert probabilities to binary predictions
binary_predictions5 = (predictions5 > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
loaded_model1.predict(values_array1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 891ms/step
# array([[0.98596674],
#        [0.9875967 ]], dtype=float32)

# %%
predictions5
# Out:
# array([[0.98596674],
#        [0.9875967 ]], dtype=float32)

# %%
binary_predictions5
# Out:
# array([[1],
#        [1]])

# %%
values_array = np.array(new_ref)

# Reshape the array to match the expected input shape of the model
# If the model expects input shape (None, 16332, 100):
values_array1 = values_array.reshape(-1, 1,100)  # Reshape to have batch size 1 and 100 features

# Now, you can use model.predict()
predictions = model5.predict(values_array1)
# Apply thresholding to convert probabilities to binary predictions
binary_predictions = (predictions > 0.5).astype(int)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
binary_predictions
# Out:
# array([[1],
#        [1]])

# %%
tra_df_d=tra_df.drop(columns=["Fatigued"])

# %%
values_array = np.array(tra_df_d)

# Reshape the array to match the expected input shape of the model
# If the model expects input shape (None, 16332, 100):
values_array1 = values_array.reshape(-1, 1,100)  # Reshape to have batch size 1 and 100 features

# Now, you can use model.predict()
predictions = model3.predict(values_array1)
# Apply thresholding to convert probabilities to binary predictions
binary_predictions = (predictions > 0.5).astype(int)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step

# %%
predictions
# Out:
# array([[0.19856164],
#        [0.0016666 ],
#        [0.00370777],
#        [0.02028173],
#        [0.02027366],
#        [0.85207987],
#        [0.48549983],
#        [0.4815787 ],
#        [0.5397678 ],
#        [0.4204444 ],
#        [0.4929576 ],
#        [0.65435094],
#        [0.5691119 ],
#        [0.5426554 ],
#        [0.22543418],
#        [0.415131  ],
#        [0.4366276 ],
#        [0.06871994],
#        [0.49704987],
#        [0.41251025],
#        [0.00142688],
#        [0.0013068 ],
#        [0.02180148],
#        [0.00363318],
#        [0.12701108],
#        [0.29135504],
#        [0.37888497],
#        [0.3741858 ],
#        [0.32840142],
#        [0.01526572],
#        [0.00125977],
#        [0.01422337],
#        [0.00966966],
#        [0.03014108],
#        [0.32717496],
#        [0.34419015],
#        [0.14313209],
#        [0.34383097],
#        [0.01817839],
#        [0.4584529 ],
#        [0.3399569 ],
#        [0.3420725 ],
#        [0.0082562 ],
# ...

# %%
binary_predictions12=pd.DataFrame(binary_predictions)

# %%
binary_predictions12.value_counts()
# Out:
# 0
# 0    75
# 1    14
# Name: count, dtype: int64

# %%
# pred

# %% [markdown]
# # Machine Learning

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.ensemble import RandomForestRegressor,StackingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
algo=[
    ( "model1", LinearRegression()),
    ( "model3", RandomForestRegressor()),
    ( "model4" ,DecisionTreeRegressor()),
    ( "model5" ,XGBRegressor()),
    ( "model6" ,CatBoostRegressor()),
    ("model7", SVR())


]
level1=RandomForestRegressor()

stack_model=StackingRegressor(estimators=algo,final_estimator=level1,cv=5)

# %%
stack_model.fit(X_train,Y_train)
# Out:
# Learning rate set to 0.064882
# 0:	learn: 0.4258817	total: 23.5ms	remaining: 23.4s
# 1:	learn: 0.4174862	total: 40.8ms	remaining: 20.3s
# 2:	learn: 0.4095061	total: 58.7ms	remaining: 19.5s
# 3:	learn: 0.4024134	total: 75.8ms	remaining: 18.9s
# 4:	learn: 0.3955127	total: 94ms	remaining: 18.7s
# 5:	learn: 0.3882769	total: 112ms	remaining: 18.5s
# 6:	learn: 0.3818955	total: 129ms	remaining: 18.3s
# 7:	learn: 0.3765125	total: 147ms	remaining: 18.2s
# 8:	learn: 0.3707485	total: 164ms	remaining: 18.1s
# 9:	learn: 0.3650922	total: 181ms	remaining: 17.9s
# 10:	learn: 0.3596876	total: 200ms	remaining: 18s
# 11:	learn: 0.3544977	total: 218ms	remaining: 18s
# 12:	learn: 0.3499410	total: 235ms	remaining: 17.8s
# 13:	learn: 0.3457057	total: 251ms	remaining: 17.7s
# 14:	learn: 0.3412214	total: 268ms	remaining: 17.6s
# 15:	learn: 0.3373355	total: 285ms	remaining: 17.5s
# 16:	learn: 0.3333932	total: 302ms	remaining: 17.5s
# 17:	learn: 0.3303344	total: 319ms	remaining: 17.4s
# ...

# %%
random1=RandomForestRegressor()
random1.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
random1.score(X_test,Y_test)
# Out:
# 0.9328520847640303

# %%
predict_1=random1.predict(X_test)

# %%
predict_1
# Out:
# array([1.  , 0.  , 1.  , ..., 1.  , 0.75, 0.9 ])

# %%
input_data=(values_n1)
array_data=np.array(input_data)
reshape_data=array_data.reshape(1,-1)
predict23=random1.predict(reshape_data)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
predict23
# Out:
# array([0.97])

# %%
predict=random1.predict(X_test)

# %%
predict[0]
# Out:
# 1.0

# %%
predict_y=stack_model.predict(X_test)

# %%
input_data=(values_n1)
array_data=np.asarray(input_data)
reshape_data=array_data.reshape(1,-1)
predict234=stack_model.predict(reshape_data)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
predict234
# Out:
# array([1.])

# %%
stack_model.score(X_test,Y_test)
# Out:
# 0.9998173206632602

# %%
import pickle
with open('rnnmodel.pkl', 'wb') as f:
    pickle.dump(model5, f)
